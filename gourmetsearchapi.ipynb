# %%
import requests

# %%
URL = 'http://webservice.recruit.co.jp/hotpepper/gourmet/v1/'

# %%
API_KEY = 'bc173991ff51c14b'

# %%
params = {
    'key': API_KEY,
    'keyword': '沖縄',
    'count': 100,
    'format':'json'
    }

# %%
res = requests.get(URL,params)

# %%
res.status_code
# Out:
# 200

# %%
res.json()
# Out:
# べ残しをお持ち帰りいただけます） ',
#     'show': 'なし',
#     'small_area': {'code': 'XX0B', 'name': '宜野湾市'},
#     'station_name': '',
#     'sub_genre': {'code': 'G002', 'name': 'ダイニングバー・バル'},
#     'tatami': 'なし ：お座敷席のご用意はございません。',
#     'tv': 'あり',
#     'urls': {'pc': 'https://www.hotpepper.jp/strJ001133589/?vos=nhppalsa000016'},
#     'wedding': 'ご相談ください。',
#     'wifi': 'なし'},
#    {'access': '330号線沿い\u3000園田バス停すぐ',
#     'address': '沖縄県沖縄市園田３-1-23',
#     'band': '不可',
#     'barrier_free': 'なし ：お手伝いできる事があればお声掛けください！',
#     'budget': {'average': '3,000円', 'code': 'B002', 'name': '2001～3000円'},
#     'budget_memo': '',
#     'capacity': 42,
#     'card': '利用不可',
#     'catch': '大人気！センベロ★ 飛び込み来店も歓迎です♪',
#     'charter': '貸切可 ：貸切最大50名様可能！人数等お気軽にご相談ください！',
#     'child': 'お子様連れ不可 ：喫煙可のため。テイクアウトできる唐揚げやたこ焼きがお子様に人気です★',
#     'close': '日',
#     'coupon_urls': {'pc': 'https://www.hotpepper.jp/strJ001249227/map/?vos=nhppalsa000016',
# ...

# %%
result = res.json()

# %%
items = result['results']['shop']

# %%
len(items)
# Out:
# 100

# %%
import pandas as pd

# %%
df = pd.DataFrame(items)
df
# Out:
#                                                access  \
# 0   グリーンスプリングスの目の前！／ＪＲ立川駅 北口より徒歩約６分／多摩モノレール立川北駅 北口...
# 1                          モノレール県庁前駅より徒歩3分、久茂地川沿いからすぐ
# 2                                      R58松山交差点ローソン2F
# 3   札幌市営地下鉄東豊線 さっぽろ駅 13番出口 徒歩2分 札幌市営地下鉄南北線 さっぽろ駅 1...
# 4        ＪＲ 田町駅 西口 徒歩2分/都営三田線 三田駅 徒歩1分/都営浅草線 三田駅 徒歩1分
# ..                                                ...
# 95    「ゆいレール県庁駅」で下車、ゆいレール下に流れる久茂地川を右手に見ながら「美栄橋」方面に4分程
# 96   【駅近5分】ゆいレール牧志駅から国際通りを県庁向けに南下、マクドナルド手前の路地を右折しすぐ左手
# 97    高速道路をご利用の場合→沖縄自動車許田ICから、国道58号、県道84号を中山方面へ車で13分。
# 98                   ゆいレール県庁前駅から久茂地交差点に向かい４℃様超えて一本目左折
# 99                                   ゆいレール 県庁前駅 徒歩6分
#
#                         address band  \
# 0     東京都立川市緑町4-5　コトブキヤビル１F　104   不可
# 1    沖縄県那覇市久茂地２－６－１　コーポカミハマビル１F   不可
# 2        沖縄県那覇市松山２－１－１８　住太郎ビル２F   不可
# 3       北海道札幌市中央区北３条西２カミヤマビルB1    不可
# 4             東京都港区芝５-20-20 B1F   不可
# ..                          ...  ...
# 95              沖縄県那覇市久茂地２-6-16   不可
# ...
